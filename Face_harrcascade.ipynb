# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavanand3116/OpenCV_Projects/blob/main/Face_harrcascade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4aa22560-07da-443c-9bee-e41b40095da1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4aa22560-07da-443c-9bee-e41b40095da1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving male.jpg to male.jpg

# %%
#READ IMAGE
img= cv2.imread('male.jpg')
#CONVERT IMAGE TO GRAY
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fb44874-f9c6-4933-a934-95c0f3030c82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fb44874-f9c6-4933-a934-95c0f3030c82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default.xml

# %%
haar = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
face= haar.detectMultiScale(gray,1.3,5)

# %%
#to draw rectangle on the face
rect= cv2.rectangle(img,(154,94),(154+261,84+261),(0,255,0),3)

# %%
plt.imshow(rect)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
