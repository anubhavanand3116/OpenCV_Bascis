# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavanand3116/OpenCV_Projects/blob/main/basic_image_dealing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib 
from PIL import Image

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff89ab02-2c13-45f9-8475-6a4392c1c8a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff89ab02-2c13-45f9-8475-6a4392c1c8a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.jpg to test.jpg

# %%
img=Image.open('test.jpg')

# %%
img
# Out:
# array([[[98, 52, 26],
#         [94, 48, 22],
#         [89, 43, 17],
#         ...,
#         [11, 12,  0],
#         [13, 14,  0],
#         [14, 15,  1]],
#
#        [[95, 49, 23],
#         [94, 48, 22],
#         [91, 45, 19],
#         ...,
#         [12, 13,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        [[91, 45, 19],
#         [93, 47, 21],
#         [93, 47, 21],
#         ...,
#         [13, 14,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        ...,
#
#        [[96, 66, 40],
#         [93, 63, 37],
#         [91, 61, 35],
#         ...,
#         [73, 94,  0],
#         [76, 97,  2],
#         [76, 97,  2]],
#
#        [[94, 64, 38],
#         [91, 61, 35],
#         [91, 61, 35],
#         ...,
#         [70, 91,  0],
#         [74, 95,  0],
#         [74, 95,  0]],
#
#        [[91, 61, 35],
#         [90, 60, 34],
#         [92, 62, 36],
#         ...,
#         [70, 91,  0],
#         [76, 97,  2],
#         [75, 96,  1]]], dtype=uint8)

# %%
img_mat= matplotlib.image.imread('test.jpg')
img_mat
# Out:
# array([[[98, 52, 26],
#         [94, 48, 22],
#         [89, 43, 17],
#         ...,
#         [11, 12,  0],
#         [13, 14,  0],
#         [14, 15,  1]],
#
#        [[95, 49, 23],
#         [94, 48, 22],
#         [91, 45, 19],
#         ...,
#         [12, 13,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        [[91, 45, 19],
#         [93, 47, 21],
#         [93, 47, 21],
#         ...,
#         [13, 14,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        ...,
#
#        [[96, 66, 40],
#         [93, 63, 37],
#         [91, 61, 35],
#         ...,
#         [73, 94,  0],
#         [76, 97,  2],
#         [76, 97,  2]],
#
#        [[94, 64, 38],
#         [91, 61, 35],
#         [91, 61, 35],
#         ...,
#         [70, 91,  0],
#         [74, 95,  0],
#         [74, 95,  0]],
#
#        [[91, 61, 35],
#         [90, 60, 34],
#         [92, 62, 36],
#         ...,
#         [70, 91,  0],
#         [76, 97,  2],
#         [75, 96,  1]]], dtype=uint8)

# %%
img_cv=cv2.imread('test.jpg')
img_cv

# %%
img_cv.shape
# Out:
# (1200, 1600, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_cv)
